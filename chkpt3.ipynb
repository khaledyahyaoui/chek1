# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data1= pd.read_csv('kc_house_data.csv')

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 40 , 20 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 15 }

        )

# %%
 plot_correlation_map(data1)

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

# %%
from sklearn.model_selection import train_test_split
y=data1[data1['sqft_living']<12000]['price']
x=data1[data1['sqft_living']<12000] ['sqft_living'] .values[:,np.newaxis]
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.20,random_state=30)

# %%
plt.scatter(data1['sqft_living'],data1['price'])
plt.show()

# %%
x=data1["sqft_living"].values[:,np.newaxis]
y=data1["price"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 62902408306.86502
# R squared 0.4996528488387417

# %%
plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x,model.predict(x),color="k")
plt.show()

# %%
plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x,model.predict(x),color="k")
plt.show()

# %%
from sklearn.model_selection import train_test_split
y=data1['price']
x=data1['grade'].values[:,np.newaxis]
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.20,random_state=30)

# %%
plt.scatter(data1['grade'],data1['price'])
plt.show()

# %%
x=data1["grade"].values[:,np.newaxis]
y=data1["price"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 68216329489.98441
# R squared 0.4573841122826078

# %%
plt.scatter(x,y,color="r")
plt.title(" Linear regression")
plt.ylabel("price")
plt.xlabel("grade")
plt.plot(x,model.predict(x),color="k")
plt.show()

# %%
from sklearn.model_selection import train_test_split
y=data1['price']
x=data1['bathrooms'].values[:,np.newaxis]
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.20,random_state=30)

# %%
plt.scatter(data1['bathrooms'],data1['price'])
plt.show()

# %%
x=data1["bathrooms"].values[:,np.newaxis]
y=data1["price"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 89550909069.11131
# R squared 0.2876816096127013

# %%
plt.scatter(x,y,color="r")
plt.title(" linear regression ")
plt.ylabel("price")
plt.xlabel("bathrooms")
plt.plot(x,model.predict(x),color="k")
plt.show()

# %%
x=data1[["bathrooms","grade","sqft_living"]]
y=data1["price"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 57230025661.905846
# R squared 0.5447729097886518

# %%
x=data1.drop(['date','id','price'],axis=1)
y=data1["price"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 37481882159.36533
# R squared 0.7018563602984709

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures 

from sklearn.metrics import mean_squared_error
from sklearn import metrics

# %%
x= data1[["bathrooms", "sqft_living"]]
y= data1["price"].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)  #splitting data
lg=LinearRegression()
poly=PolynomialFeatures(degree=3)

x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  58540531925.76783
# R squared:  0.5343486972131413

# %%
x= data1["bathrooms"].values.reshape(-1,1)
y= data1["price"].values

poly = PolynomialFeatures(degree = 2) 
x_poly = poly.fit_transform(x) 
poly.fit(x_poly, y) 
lg=LinearRegression()
lg.fit(x_poly, y) 

plt.scatter(x, y, color="r")
plt.title("Linear regression")
plt.ylabel("price")
plt.xlabel("bathrooms")
plt.plot(x, lg.predict(poly.fit_transform(x)), color="k")

# %%
x= data1["sqft_living"].values.reshape(-1,1)
y= data1["price"].values
poly = PolynomialFeatures(degree = 2) 
x_poly = poly.fit_transform(x) 
poly.fit(x_poly, y) 
lg=LinearRegression()
lg.fit(x_poly, y) 

plt.scatter(x, y, color="r")
plt.title("Linear regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x, lg.predict(poly.fit_transform(x)), color="k")

# %%
x= data1["grade"].values.reshape(-1,1)
y= data1["price"].values
poly = PolynomialFeatures(degree = 2) 
x_poly = poly.fit_transform(x) 
poly.fit(x_poly, y) 
lg=LinearRegression()
lg.fit(x_poly, y) 

plt.scatter(x, y, color="r")
plt.title("Linear regression")
plt.ylabel("price")
plt.xlabel("grade")
plt.plot(x, lg.predict(poly.fit_transform(x)), color="k")

# %%
x= data1[["sqft_living", "grade", "bathrooms"]]
y= data1["price"].values
poly = PolynomialFeatures(degree = 2) 
x_poly = poly.fit_transform(x) 
poly.fit(x_poly, y) 
lg=LinearRegression()
lg.fit(x_poly, y) 


print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  58540531925.76783
# R squared:  0.5343486972131413

# %%
x.shape
# Out:
# (21613, 3)

# %%
y.shape
# Out:
# (21613,)

# %%
data1.drop('price', axis=1)  #we have more than one input
y=data1["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression() #build linear regression model
model.fit(x_train,y_train) #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance

print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 57230025661.90677
# R squared 0.5447729097886446

# %%
#preparing data for logistic regression
data1["price"]=data1["sqft_living"].map({"yes": 1, "no": 0})   #convert admitted variable into numerical
data1.head()
# Out:
#            id             date  price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000    NaN         3       1.00         1180
# 1  6414100192  20141209T000000    NaN         3       2.25         2570
# 2  5631500400  20150225T000000    NaN         2       1.00          770
# 3  2487200875  20141209T000000    NaN         4       3.00         1960
# 4  1954400510  20150218T000000    NaN         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...
